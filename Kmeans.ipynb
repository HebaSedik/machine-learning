# %% [markdown]
# <a href="https://colab.research.google.com/github/HebaSedik/machine-learning/blob/master/Kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
X= -2 * np.random.rand(100,2)
X1 = 1 + 2 * np.random.rand(50,2)
X[50:100, :] = X1
plt.scatter(X[ : , 0], X[ :, 1], s = 50, c = 'b')
plt.show()

# %%
Kmean = KMeans(n_clusters=2, random_state=0, n_init="auto")
Kmean.fit(X)
# Out:
# KMeans(n_clusters=2, n_init='auto', random_state=0)

# %%
plt.scatter(X[ : , 0], X[ : , 1], s =50, c='b')
plt.scatter(1.95471434,  2.02593572, s=200, c='g', marker='s')
plt.scatter(-1.07084079, -1.13423498, s=200, c='r', marker='s')
plt.show()

# %%
sample_test=np.array([-3.0,-3.0])
second_test=sample_test.reshape(1, -1)
Kmean.predict(second_test)
# Out:
# array([0], dtype=int32)

# %%
second_test
# Out:
# array([[-3., -3.]])
